# %% [markdown]
# # Denoiser Example

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
import os
import tensorflow as tf

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping

# %matplotlib inline

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.5.5

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
# Out:
# 2022-04-06 23:12:16.317301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:12:16.317460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:12:16.321687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:12:16.321817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:12:16.321936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:12:16.322052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
import os
for dirname, _, filenames in os.walk('kaggle'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# kaggle/denoising-dirty-documents/train_cleaned.zip
# kaggle/denoising-dirty-documents/train.zip
# kaggle/denoising-dirty-documents/test.zip
# kaggle/denoising-dirty-documents/sampleSubmission.csv.zip
# kaggle/working/sampleSubmission.csv
# kaggle/working/train_cleaned/60.png
# kaggle/working/train_cleaned/209.png
# kaggle/working/train_cleaned/50.png
# kaggle/working/train_cleaned/137.png
# kaggle/working/train_cleaned/75.png
# kaggle/working/train_cleaned/188.png
# kaggle/working/train_cleaned/213.png
# kaggle/working/train_cleaned/189.png
# kaggle/working/train_cleaned/113.png
# kaggle/working/train_cleaned/171.png
# kaggle/working/train_cleaned/150.png
# kaggle/working/train_cleaned/104.png
# kaggle/working/train_cleaned/146.png
# kaggle/working/train_cleaned/53.png
# kaggle/working/train_cleaned/17.png
# kaggle/working/train_cleaned/71.png
# kaggle/working/train_cleaned/98.png
# kaggle/working/train_cleaned/168.png
# kaggle/working/train_cleaned/204.png
# kaggle/working/train_cleaned/72.png
# kaggle/working/train_cleaned/215.png
# kaggle/working/train_cleaned/32.png
# kaggle/working/train_cleaned/107.png
# kaggle/working/train_cleaned/35.png
# kaggle/working/train_cleaned/92.png
# kaggle/working/train_cleaned/182.png
# kaggle/working/train_cleaned/93.png
# kaggle/working/train_cleaned/59.png
# kaggle/working/train_cleaned/153.png
# kaggle/working/train_cleaned/63.png
# kaggle/working/train_cleaned/5.png
# kaggle/working/train_cleaned/156.png
# kaggle/working/train_cleaned/185.png
# kaggle/working/train_cleaned/120.png
# kaggle/working/train_cleaned/80.png
# kaggle/working/train_cleaned/69.png
# kaggle/working/train_cleaned/198.png
# kaggle/working/train_cleaned/15.png
# kaggle/working/train_cleaned/87.png
# kaggle/working/train_cleaned/2.png
# kaggle/working/train_cleaned/125.png
# kaggle/working/train_cleaned/207.png
# kaggle/working/train_cleaned/89.png
# kaggle/working/train_cleaned/27.png
# kaggle/working/train_cleaned/141.png
# kaggle/working/train_cleaned/195.png
# kaggle/working/train_cleaned/44.png
# kaggle/working/train_cleaned/48.png
# kaggle/working/train_cleaned/159.png
# kaggle/working/train_cleaned/33.png
# kaggle/working/train_cleaned/74.png
# kaggle/working/train_cleaned/143.png
# kaggle/working/train_cleaned/161.png
# kaggle/working/train_cleaned/162.png
# kaggle/working/train_cleaned/42.png
# kaggle/working/train_cleaned/56.png
# kaggle/working/train_cleaned/117.png
# kaggle/working/train_cleaned/38.png
# kaggle/working/train_cleaned/102.png
# kaggle/working/train_cleaned/149.png
# kaggle/working/train_cleaned/170.png
# kaggle/working/train_cleaned/147.png
# kaggle/working/train_cleaned/90.png
# kaggle/working/train_cleaned/36.png
# kaggle/working/train_cleaned/110.png
# kaggle/working/train_cleaned/144.png
# kaggle/working/train_cleaned/8.png
# kaggle/working/train_cleaned/101.png
# kaggle/working/train_cleaned/65.png
# kaggle/working/train_cleaned/6.png
# kaggle/working/train_cleaned/123.png
# kaggle/working/train_cleaned/119.png
# kaggle/working/train_cleaned/23.png
# kaggle/working/train_cleaned/114.png
# kaggle/working/train_cleaned/21.png
# kaggle/working/train_cleaned/20.png
# kaggle/working/train_cleaned/126.png
# kaggle/working/train_cleaned/99.png
# kaggle/working/train_cleaned/116.png
# kaggle/working/train_cleaned/135.png
# kaggle/working/train_cleaned/62.png
# kaggle/working/train_cleaned/108.png
# kaggle/working/train_cleaned/179.png
# kaggle/working/train_cleaned/26.png
# kaggle/working/train_cleaned/78.png
# kaggle/working/train_cleaned/173.png
# kaggle/working/train_cleaned/122.png
# kaggle/working/train_cleaned/129.png
# kaggle/working/train_cleaned/206.png
# kaggle/working/train_cleaned/138.png
# kaggle/working/train_cleaned/192.png
# kaggle/working/train_cleaned/11.png
# kaggle/working/train_cleaned/84.png
# kaggle/working/train_cleaned/180.png
# kaggle/working/train_cleaned/66.png
# kaggle/working/train_cleaned/57.png
# kaggle/working/train_cleaned/96.png
# kaggle/working/train_cleaned/12.png
# kaggle/working/train_cleaned/167.png
# kaggle/working/train_cleaned/186.png
# kaggle/working/train_cleaned/24.png
# kaggle/working/train_cleaned/210.png
# kaggle/working/train_cleaned/203.png
# kaggle/working/train_cleaned/83.png
# kaggle/working/train_cleaned/41.png
# kaggle/working/train_cleaned/134.png
# kaggle/working/train_cleaned/54.png
# kaggle/working/train_cleaned/165.png
# kaggle/working/train_cleaned/200.png
# kaggle/working/train_cleaned/174.png
# kaggle/working/train_cleaned/152.png
# kaggle/working/train_cleaned/183.png
# kaggle/working/train_cleaned/176.png
# kaggle/working/train_cleaned/29.png
# kaggle/working/train_cleaned/131.png
# kaggle/working/train_cleaned/177.png
# kaggle/working/train_cleaned/18.png
# kaggle/working/train_cleaned/77.png
# kaggle/working/train_cleaned/128.png
# kaggle/working/train_cleaned/86.png
# kaggle/working/train_cleaned/95.png
# kaggle/working/train_cleaned/191.png
# kaggle/working/train_cleaned/132.png
# kaggle/working/train_cleaned/201.png
# kaggle/working/train_cleaned/194.png
# kaggle/working/train_cleaned/111.png
# kaggle/working/train_cleaned/164.png
# kaggle/working/train_cleaned/45.png
# kaggle/working/train_cleaned/158.png
# kaggle/working/train_cleaned/47.png
# kaggle/working/train_cleaned/3.png
# kaggle/working/train_cleaned/197.png
# kaggle/working/train_cleaned/39.png
# kaggle/working/train_cleaned/155.png
# kaggle/working/train_cleaned/212.png
# kaggle/working/train_cleaned/81.png
# kaggle/working/train_cleaned/105.png
# kaggle/working/train_cleaned/9.png
# kaggle/working/train_cleaned/68.png
# kaggle/working/train_cleaned/14.png
# kaggle/working/train_cleaned/216.png
# kaggle/working/train_cleaned/140.png
# kaggle/working/train_cleaned/30.png
# kaggle/working/train_cleaned/51.png
# kaggle/working/train/60.png
# kaggle/working/train/209.png
# kaggle/working/train/50.png
# kaggle/working/train/137.png
# kaggle/working/train/75.png
# kaggle/working/train/188.png
# kaggle/working/train/213.png
# kaggle/working/train/189.png
# kaggle/working/train/113.png
# kaggle/working/train/171.png
# kaggle/working/train/150.png
# kaggle/working/train/104.png
# kaggle/working/train/146.png
# kaggle/working/train/53.png
# kaggle/working/train/17.png
# kaggle/working/train/71.png
# kaggle/working/train/98.png
# kaggle/working/train/168.png
# kaggle/working/train/204.png
# kaggle/working/train/72.png
# kaggle/working/train/215.png
# kaggle/working/train/32.png
# kaggle/working/train/107.png
# kaggle/working/train/35.png
# kaggle/working/train/92.png
# kaggle/working/train/182.png
# kaggle/working/train/93.png
# kaggle/working/train/59.png
# kaggle/working/train/153.png
# kaggle/working/train/63.png
# kaggle/working/train/5.png
# kaggle/working/train/156.png
# kaggle/working/train/185.png
# kaggle/working/train/120.png
# kaggle/working/train/80.png
# kaggle/working/train/69.png
# kaggle/working/train/198.png
# kaggle/working/train/15.png
# kaggle/working/train/87.png
# kaggle/working/train/2.png
# kaggle/working/train/125.png
# kaggle/working/train/207.png
# kaggle/working/train/89.png
# kaggle/working/train/27.png
# kaggle/working/train/141.png
# kaggle/working/train/195.png
# kaggle/working/train/44.png
# kaggle/working/train/48.png
# kaggle/working/train/159.png
# kaggle/working/train/33.png
# kaggle/working/train/74.png
# kaggle/working/train/143.png
# kaggle/working/train/161.png
# kaggle/working/train/162.png
# kaggle/working/train/42.png
# kaggle/working/train/56.png
# kaggle/working/train/117.png
# kaggle/working/train/38.png
# kaggle/working/train/102.png
# kaggle/working/train/149.png
# kaggle/working/train/170.png
# kaggle/working/train/147.png
# kaggle/working/train/90.png
# kaggle/working/train/36.png
# kaggle/working/train/110.png
# kaggle/working/train/144.png
# kaggle/working/train/8.png
# kaggle/working/train/101.png
# kaggle/working/train/65.png
# kaggle/working/train/6.png
# kaggle/working/train/123.png
# kaggle/working/train/119.png
# kaggle/working/train/23.png
# kaggle/working/train/114.png
# kaggle/working/train/21.png
# kaggle/working/train/20.png
# kaggle/working/train/126.png
# kaggle/working/train/99.png
# kaggle/working/train/116.png
# kaggle/working/train/135.png
# kaggle/working/train/62.png
# kaggle/working/train/108.png
# kaggle/working/train/179.png
# kaggle/working/train/26.png
# kaggle/working/train/78.png
# kaggle/working/train/173.png
# kaggle/working/train/122.png
# kaggle/working/train/129.png
# kaggle/working/train/206.png
# kaggle/working/train/138.png
# kaggle/working/train/192.png
# kaggle/working/train/11.png
# kaggle/working/train/84.png
# kaggle/working/train/180.png
# kaggle/working/train/66.png
# kaggle/working/train/57.png
# kaggle/working/train/96.png
# kaggle/working/train/12.png
# kaggle/working/train/167.png
# kaggle/working/train/186.png
# kaggle/working/train/24.png
# kaggle/working/train/210.png
# kaggle/working/train/203.png
# kaggle/working/train/83.png
# kaggle/working/train/41.png
# kaggle/working/train/134.png
# kaggle/working/train/54.png
# kaggle/working/train/165.png
# kaggle/working/train/200.png
# kaggle/working/train/174.png
# kaggle/working/train/152.png
# kaggle/working/train/183.png
# kaggle/working/train/176.png
# kaggle/working/train/29.png
# kaggle/working/train/131.png
# kaggle/working/train/177.png
# kaggle/working/train/18.png
# kaggle/working/train/77.png
# kaggle/working/train/128.png
# kaggle/working/train/86.png
# kaggle/working/train/95.png
# kaggle/working/train/191.png
# kaggle/working/train/132.png
# kaggle/working/train/201.png
# kaggle/working/train/194.png
# kaggle/working/train/111.png
# kaggle/working/train/164.png
# kaggle/working/train/45.png
# kaggle/working/train/158.png
# kaggle/working/train/47.png
# kaggle/working/train/3.png
# kaggle/working/train/197.png
# kaggle/working/train/39.png
# kaggle/working/train/155.png
# kaggle/working/train/212.png
# kaggle/working/train/81.png
# kaggle/working/train/105.png
# kaggle/working/train/9.png
# kaggle/working/train/68.png
# kaggle/working/train/14.png
# kaggle/working/train/216.png
# kaggle/working/train/140.png
# kaggle/working/train/30.png
# kaggle/working/train/51.png
# kaggle/working/test/151.png
# kaggle/working/test/115.png
# kaggle/working/test/187.png
# kaggle/working/test/46.png
# kaggle/working/test/73.png
# kaggle/working/test/205.png
# kaggle/working/test/160.png
# kaggle/working/test/1.png
# kaggle/working/test/154.png
# kaggle/working/test/19.png
# kaggle/working/test/82.png
# kaggle/working/test/67.png
# kaggle/working/test/112.png
# kaggle/working/test/31.png
# kaggle/working/test/127.png
# kaggle/working/test/34.png
# kaggle/working/test/91.png
# kaggle/working/test/70.png
# kaggle/working/test/190.png
# kaggle/working/test/100.png
# kaggle/working/test/178.png
# kaggle/working/test/106.png
# kaggle/working/test/169.png
# kaggle/working/test/61.png
# kaggle/working/test/22.png
# kaggle/working/test/58.png
# kaggle/working/test/163.png
# kaggle/working/test/181.png
# kaggle/working/test/139.png
# kaggle/working/test/25.png
# kaggle/working/test/142.png
# kaggle/working/test/97.png
# kaggle/working/test/175.png
# kaggle/working/test/7.png
# kaggle/working/test/172.png
# kaggle/working/test/40.png
# kaggle/working/test/10.png
# kaggle/working/test/79.png
# kaggle/working/test/49.png
# kaggle/working/test/88.png
# kaggle/working/test/157.png
# kaggle/working/test/55.png
# kaggle/working/test/52.png
# kaggle/working/test/118.png
# kaggle/working/test/109.png
# kaggle/working/test/184.png
# kaggle/working/test/133.png
# kaggle/working/test/196.png
# kaggle/working/test/16.png
# kaggle/working/test/103.png
# kaggle/working/test/208.png
# kaggle/working/test/94.png
# kaggle/working/test/121.png
# kaggle/working/test/64.png
# kaggle/working/test/193.png
# kaggle/working/test/28.png
# kaggle/working/test/145.png
# kaggle/working/test/85.png
# kaggle/working/test/136.png
# kaggle/working/test/211.png
# kaggle/working/test/130.png
# kaggle/working/test/124.png
# kaggle/working/test/37.png
# kaggle/working/test/43.png
# kaggle/working/test/202.png
# kaggle/working/test/214.png
# kaggle/working/test/13.png
# kaggle/working/test/76.png
# kaggle/working/test/148.png
# kaggle/working/test/4.png
# kaggle/working/test/166.png
# kaggle/working/test/199.png

# %%
# path to zipped & working directories
path_zip = 'kaggle/denoising-dirty-documents/'
path = 'kaggle/working/'

# %%
# unzip files first to working directory
# We could use also unzipped data source, but why not to learn something new?
with zipfile.ZipFile(path_zip + 'train.zip', 'r') as zip_ref:
    zip_ref.extractall(path)

with zipfile.ZipFile(path_zip + 'test.zip', 'r') as zip_ref:
    zip_ref.extractall(path)  
    
with zipfile.ZipFile(path_zip + 'train_cleaned.zip', 'r') as zip_ref:
    zip_ref.extractall(path)  
    
with zipfile.ZipFile(path_zip + 'sampleSubmission.csv.zip', 'r') as zip_ref:
    zip_ref.extractall(path)

# %%
# store image names in list for later use
train_img = sorted(os.listdir(path + '/train'))
train_cleaned_img = sorted(os.listdir(path + '/train_cleaned'))
test_img = sorted(os.listdir(path + '/test'))

# %% [markdown]
# # Data preparation

# %%
# prepare function
def process_image(path):
    img = cv2.imread(path)
    img = np.asarray(img, dtype="float32")
    img = cv2.resize(img, (540, 420))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = img/255.0
    img = np.reshape(img, (420, 540, 1))
    
    return img

# %%
# preprocess images
train = []
train_cleaned = []
test = []

for f in sorted(os.listdir(path + 'train/')):
    train.append(process_image(path + 'train/' + f))

for f in sorted(os.listdir(path + 'train_cleaned/')):
    train_cleaned.append(process_image(path + 'train_cleaned/' + f))
   
for f in sorted(os.listdir(path + 'test/')):
    test.append(process_image(path + 'test/' + f))

# %% [markdown]
# # Exploratory data analysis

# %%
plt.figure(figsize=(15,25))
for i in range(0,8,2):
    plt.subplot(4,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train[i][:,:,0], cmap='gray')
    plt.title('Noise image: {}'.format(train_img[i]))
    
    plt.subplot(4,2,i+2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_cleaned[i][:,:,0], cmap='gray')
    plt.title('Denoised image: {}'.format(train_img[i]))

plt.show()

# %% [markdown]
# # Split data

# %%
# convert list to numpy array
X_train = np.asarray(train)
Y_train = np.asarray(train_cleaned)
X_test = np.asarray(test)

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.15)

# %% [markdown]
# # Modeling

# %%
def model():
    input_layer = Input(shape=(420, 540, 1))  # we might define (None,None,1) here, but in model summary dims would not be visible
    
    # encoding
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)

    x = MaxPooling2D((2, 2), padding='same')(x)
    
    x = Dropout(0.5)(x)

    # decoding
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)

    x = UpSampling2D((2, 2))(x)

    output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    model = Model(inputs=[input_layer], outputs=[output_layer])
    model.compile(optimizer='adam' , loss='mean_squared_error', metrics=['mae'])

    return model

# %%
model = model()
# Out:
# 2022-04-06 23:13:08.409698: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-06 23:13:08.582476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:08.582687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:08.582856: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:08.583012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:08.583166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:08.583321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.130403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.130655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.130824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.131025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.131198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.131347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22846 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:02:00.0, compute capability: 7.5
# 2022-04-06 23:13:09.131642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-06 23:13:09.131778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9619 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 420, 540, 1)]     0
#
#  conv2d (Conv2D)             (None, 420, 540, 64)      640
#
#  conv2d_1 (Conv2D)           (None, 420, 540, 128)     73856
#
#  batch_normalization (BatchN  (None, 420, 540, 128)    512
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 210, 270, 128)    0
#  )
#
#  dropout (Dropout)           (None, 210, 270, 128)     0
#
#  conv2d_2 (Conv2D)           (None, 210, 270, 128)     147584
#
#  conv2d_3 (Conv2D)           (None, 210, 270, 64)      73792
#
#  batch_normalization_1 (Batc  (None, 210, 270, 64)     256
#  hNormalization)
#
#  up_sampling2d (UpSampling2D  (None, 420, 540, 64)     0
#  )
#
#  conv2d_4 (Conv2D)           (None, 420, 540, 1)       577
#
# =================================================================
# Total params: 297,217
# Trainable params: 296,833
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# # Train model

# %%
callback = EarlyStopping(monitor='loss', patience=30)

# %%
history = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), epochs=600, batch_size=24, verbose=0, callbacks=[callback])
# Out:
# 2022-04-06 23:13:56.506118: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 2022-04-06 23:13:57.053600: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %% [markdown]
# # Plot error evolution on epochs

# %%
# Check how loss & mae went down
epoch_loss = history.history['loss']
epoch_val_loss = history.history['val_loss']
epoch_mae = history.history['mae']
epoch_val_mae = history.history['val_mae']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mae)), epoch_mae, 'b-', linewidth=2, label='Train MAE')
plt.plot(range(0,len(epoch_val_mae)), epoch_val_mae, 'r-', linewidth=2,label='Val MAE')
plt.title('Evolution of MAE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %% [markdown]
# # Evaluation

# %%
# predict/clean test images
Y_test = model.predict(X_test, batch_size=16)

# %%
plt.figure(figsize=(15,25))
for i in range(0,8,2):
    plt.subplot(4,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_test[i][:,:,0], cmap='gray')
    plt.title('Noisy image: {}'.format(test_img[i]))
    
    plt.subplot(4,2,i+2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(Y_test[i][:,:,0], cmap='gray')
    plt.title('Denoised by autoencoder: {}'.format(test_img[i]))

plt.show()
